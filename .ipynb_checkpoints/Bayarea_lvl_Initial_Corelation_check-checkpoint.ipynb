# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("resources/HistoricalData/BayAreaSummary.csv")

# %%
df.reset_index(inplace=True, drop=True)

# %%
df = df.drop(["Unnamed: 0", "Year"], axis=1)

# %%
df.head()
# Out:
#     TotalPop  HouseholdPop  EstHouseholds  Net_Migration  Immigration  \
# 0  6063929.0     5914746.0      2268498.0        26173.0      45028.0
# 1  6150405.0     5996580.0      2288446.0        32671.0      49980.0
# 2  6236622.0     6084002.0      2308925.0        30248.0      50644.0
# 3  6296661.0     6144064.0      2326344.0       -13351.0      41806.0
# 4  6330094.0     6180022.0      2344173.0       -18169.0      32940.0
#
#    Domestic_Migration  Population  Employers  Employees  AvgAnnualPay  \
# 0            -18855.0   6063929.0   184128.0  2942366.0  28240.444444
# 1            -17309.0   6150405.0   195298.0  2887645.0  30080.888889
# 2            -20396.0   6236622.0   202087.0  2879500.0  30708.555556
# 3            -55157.0   6296661.0   199363.0  2900397.0  31565.111111
# 4            -51109.0   6330094.0   214307.0  2964060.0  32787.777778
#
#    New Homes Constructed  HousingUnits  Avg.Median Home price  Interest_Rate  \
# 0                16396.0     2385091.0                 234197           9.34
# 1                16857.0     2401487.0                 233964           8.11
# 2                13781.0     2418344.0                 232320           7.13
# 3                14482.0     2432125.0                 238903           7.49
# 4                14371.0     2446607.0                 239315           7.85
#
#    HU_HH_Ratio
# 0     1.051397
# 1     1.049396
# 2     1.047390
# 3     1.045471
# 4     1.043697

# %%
df_new = df[["Avg.Median Home price","TotalPop","HouseholdPop","EstHouseholds" ,"Net_Migration","Immigration","Interest_Rate"]]

# %%
df_new1 = df[["Avg.Median Home price","Domestic_Migration","Employers", "Employees","AvgAnnualPay","New Homes Constructed","HU_HH_Ratio"]]

# %%
scatter_matrix(df_new, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a19c90198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a8b4f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a8f70b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a9300b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a96b0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a96b0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a9ccc88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1aa0f208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aa49748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aa74518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aaad518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aae7518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ab21518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aabd4a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ab8d0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1abc80b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ac040b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ac3a5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ac66ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aca0ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1acd8ba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ad1c128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ad48518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ad814a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1adba4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1adf39e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1adffe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ae57f98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ae8ef98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1aed4518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1af0e518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1af3a978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1af73908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1afab908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1afe6908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1af7ef60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b053438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b08d898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b0c8898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b1007b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b12beb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b170358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b1ab358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b1e3278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b20ceb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b245f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b27deb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b2b7eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b2a14a8>]], dtype=object)

# %%
plt.show()

# %%
scatter_matrix(df_new1, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b55a908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b7bc9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b7df5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b815240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b84f240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b84f278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b8b0c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b8f3160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b92d6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b899208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b991c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b9c8cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ba04cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ba40cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ba75780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1baac7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bae97f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bb1f710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bb46e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bb83e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bbbbe80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bbf6e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bc31e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bc659b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bc9ca20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bcd8a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bd12a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bd47630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bd7f6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bdb86a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bdf35c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1be02b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1be600f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1be99400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bed2390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bf0e390>]], dtype=object)

# %%
plt.show()

# %%
df.corr()
# Out:
#                        TotalPop  HouseholdPop  EstHouseholds  Net_Migration  \
# TotalPop               1.000000      0.999967       0.987640       0.176800
# HouseholdPop           0.999967      1.000000       0.987601       0.173730
# EstHouseholds          0.987640      0.987601       1.000000       0.123780
# Net_Migration          0.176800      0.173730       0.123780       1.000000
# Immigration           -0.041346     -0.041171      -0.043409      -0.155980
# Domestic_Migration     0.175526      0.172599       0.126114       0.975426
# Population             0.980072      0.980555       0.961840       0.110605
# Employers              0.938529      0.938395       0.923665       0.143713
# Employees              0.814899      0.816856       0.770957       0.294666
# AvgAnnualPay           0.970871      0.970787       0.967366       0.125181
# New Homes Constructed -0.075163     -0.069854      -0.057944      -0.305641
# HousingUnits           0.940152      0.940259       0.950957       0.045093
# Avg.Median Home price  0.799286      0.800972       0.814675      -0.180791
# Interest_Rate         -0.876945     -0.876772      -0.848218      -0.055196
# HU_HH_Ratio            0.152787      0.153174       0.153226      -0.215355
#
#                        Immigration  Domestic_Migration  Population  Employers  \
# TotalPop                 -0.041346            0.175526    0.980072   0.938529
# HouseholdPop             -0.041171            0.172599    0.980555   0.938395
# EstHouseholds            -0.043409            0.126114    0.961840   0.923665
# Net_Migration            -0.155980            0.975426    0.110605   0.143713
# Immigration               1.000000           -0.369778   -0.073608  -0.171828
# Domestic_Migration       -0.369778            1.000000    0.120458   0.173508
# Population               -0.073608            0.120458    1.000000   0.973688
# Employers                -0.171828            0.173508    0.973688   1.000000
# Employees                 0.196253            0.233397    0.772258   0.694902
# AvgAnnualPay             -0.070669            0.133513    0.989333   0.972157
# New Homes Constructed     0.387770           -0.373992   -0.114884  -0.247501
# HousingUnits             -0.117368            0.068596    0.972967   0.969255
# Avg.Median Home price     0.177585           -0.209670    0.815038   0.738533
# Interest_Rate             0.208458           -0.098418   -0.932749  -0.933747
# HU_HH_Ratio              -0.246281           -0.147636    0.331107   0.429378
#
#                        Employees  AvgAnnualPay  New Homes Constructed  \
# TotalPop                0.814899      0.970871              -0.075163
# HouseholdPop            0.816856      0.970787              -0.069854
# EstHouseholds           0.770957      0.967366              -0.057944
# Net_Migration           0.294666      0.125181              -0.305641
# Immigration             0.196253     -0.070669               0.387770
# Domestic_Migration      0.233397      0.133513              -0.373992
# Population              0.772258      0.989333              -0.114884
# Employers               0.694902      0.972157              -0.247501
# Employees               1.000000      0.735657               0.321188
# AvgAnnualPay            0.735657      1.000000              -0.154164
# New Homes Constructed   0.321188     -0.154164               1.000000
# HousingUnits            0.647884      0.988255              -0.192804
# Avg.Median Home price   0.725683      0.829636               0.291740
# Interest_Rate          -0.548573     -0.919119               0.307883
# HU_HH_Ratio            -0.160065      0.365919              -0.451536
#
#                        HousingUnits  Avg.Median Home price  Interest_Rate  \
# TotalPop                   0.940152               0.799286      -0.876945
# HouseholdPop               0.940259               0.800972      -0.876772
# EstHouseholds              0.950957               0.814675      -0.848218
# Net_Migration              0.045093              -0.180791      -0.055196
# Immigration               -0.117368               0.177585       0.208458
# Domestic_Migration         0.068596              -0.209670      -0.098418
# Population                 0.972967               0.815038      -0.932749
# Employers                  0.969255               0.738533      -0.933747
# Employees                  0.647884               0.725683      -0.548573
# AvgAnnualPay               0.988255               0.829636      -0.919119
# New Homes Constructed     -0.192804               0.291740       0.307883
# HousingUnits               1.000000               0.807392      -0.925167
# Avg.Median Home price      0.807392               1.000000      -0.683790
# Interest_Rate             -0.925167              -0.683790       1.000000
# HU_HH_Ratio                0.451335               0.230073      -0.506030
#
#                        HU_HH_Ratio
# TotalPop                  0.152787
# HouseholdPop              0.153174
# EstHouseholds             0.153226
# Net_Migration            -0.215355
# Immigration              -0.246281
# Domestic_Migration       -0.147636
# Population                0.331107
# Employers                 0.429378
# Employees                -0.160065
# AvgAnnualPay              0.365919
# New Homes Constructed    -0.451536
# HousingUnits              0.451335
# Avg.Median Home price     0.230073
# Interest_Rate            -0.506030
# HU_HH_Ratio               1.000000

# %%
Final_df = df[["Avg.Median Home price", "AvgAnnualPay","EstHouseholds", "Employees","HU_HH_Ratio"]]

# %%
Final_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e9304b37fd3b> in <module>()
# ----> 1 Final_df.head()
#
# NameError: name 'Final_df' is not defined

# %%
scatter_matrix(Final_df, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bf6cef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c3853c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c3aaf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c3e1f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c4264a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c4264e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c48bb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c4c3b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c5070b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c5344a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c56e4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c5a64a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c5dd9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c5e7b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c644f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c678f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c6c14a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c6f94a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c724978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c75f908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c79a908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c7d2908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c76a5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c83d438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c876908>]], dtype=object)

# %%
plt.show()

# %%
Final_df.corr()
# Out:
#                        Avg.Median Home price  AvgAnnualPay  EstHouseholds  \
# Avg.Median Home price               1.000000      0.829636       0.814675
# AvgAnnualPay                        0.829636      1.000000       0.967366
# EstHouseholds                       0.814675      0.967366       1.000000
# Employees                           0.725683      0.735657       0.770957
#
#                        Employees
# Avg.Median Home price   0.725683
# AvgAnnualPay            0.735657
# EstHouseholds           0.770957
# Employees               1.000000

# %% [markdown]
# ## Visualize each variable individually

# %%
Final_df.plot(kind="scatter", x="Avg.Median Home price", y="AvgAnnualPay", alpha=0.5)
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='AvgAnnualPay',data=Final_df,fit_reg=True) 
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='EstHouseholds',data=Final_df,fit_reg=True) 
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='Employees',data=Final_df,fit_reg=True) 
plt.show()
