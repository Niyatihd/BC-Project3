# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("resources/HistoricalData/CountyLevelSummary.csv")

# %%
df.reset_index(inplace=True, drop=True)

# %%
df = df.drop(["Unnamed: 0", "Year"], axis=1)

# %%
df.head()
# Out:
#     County  TotalPop  Employers  Employees  AvgAnnualPay  \
# 0  Alameda   1284782      35264     589348         29262
# 1  Alameda   1302709      37575     580372         30739
# 2  Alameda   1318127      38998     581604         31202
# 3  Alameda   1327526      38190     582410         32175
# 4  Alameda   1333031      41139     604087         33263
#
#    New Homes Constructed  Avg.Median Home price  EstHouseholds  Net_Migration  \
# 0                    226               229890.0       483745.0         3684.0
# 1                   2652               223200.0       485019.0         5100.0
# 2                   3049               217370.0       488485.0         -432.0
# 3                   2617               210010.0       492503.0        -5262.0
# 4                   3515               207880.0       495897.0        -6877.0
#
#    Immigration  Domestic_Migration  Interest_Rate
# 0       8600.0             -4916.0           9.34
# 1       8716.0             -3616.0           8.11
# ...

# %%
df_alameda = df.loc[df["County"] =="Alameda"]

# %%
df_alameda
# Out:
#      County  TotalPop  Employers  Employees  AvgAnnualPay  \
# 0   Alameda   1284782      35264     589348         29262
# 1   Alameda   1302709      37575     580372         30739
# 2   Alameda   1318127      38998     581604         31202
# 3   Alameda   1327526      38190     582410         32175
# 4   Alameda   1333031      41139     604087         33263
# 5   Alameda   1340509      40636     620381         34505
# 6   Alameda   1361330      39571     631383         37045
# 7   Alameda   1389000      43683     651492         38809
# 8   Alameda   1412315      44947     672416         41098
# 9   Alameda   1437136      43448     697215         45155
# 10  Alameda   1457185      44645     697181         46489
# 11  Alameda   1467063      46319     681988         47307
# 12  Alameda   1467892      47393     677990         48822
# 13  Alameda   1466407      47498     672203         51402
# 14  Alameda   1462736      47138     675480         53152
# ...

# %%
# df_new = df[["Avg.Median Home price","TotalPop","HouseholdPop","EstHouseholds" ,"Net_Migration","Immigration","Interest_Rate"]]

# %%
df_new1 = df_alameda[["Avg.Median Home price","Immigration","Employers", "Employees","AvgAnnualPay","New Homes Constructed","EstHouseholds"]]

# %%
# scatter_matrix(df_new, alpha=0.2, figsize=(12, 12), diagonal='kde')

# %%
# plt.show()

# %%
scatter_matrix(df_new1, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10f96a908>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1105ba748>]], dtype=object)

# %%
plt.show()

# %%
df_alameda.corr()
# Out:
#                        TotalPop  Employers  Employees  AvgAnnualPay  \
# TotalPop               1.000000   0.971804   0.813726      0.975461
# Employers              0.971804   1.000000   0.711834      0.979868
# Employees              0.813726   0.711834   1.000000      0.745824
# AvgAnnualPay           0.975461   0.979868   0.745824      1.000000
# New Homes Constructed -0.090933  -0.170805   0.352906     -0.144711
# Avg.Median Home price  0.835920   0.783928   0.824421      0.848847
# EstHouseholds          0.990542   0.975713   0.803312      0.991875
# Net_Migration          0.161290   0.144846   0.141829      0.114171
# Immigration            0.431816   0.337075   0.614992      0.403226
# Domestic_Migration     0.073320   0.075543   0.019482      0.033245
# Interest_Rate         -0.924771  -0.938468  -0.577552     -0.915722
#
#                        New Homes Constructed  Avg.Median Home price  \
# TotalPop                           -0.090933               0.835920
# ...

# %%
Final_df = df_alameda[["Avg.Median Home price", "AvgAnnualPay","EstHouseholds", "Employees"]]

# %%
Final_df.head()
# Out:
#    Avg.Median Home price  AvgAnnualPay  EstHouseholds  Employees
# 0               229890.0         29262       483745.0     589348
# 1               223200.0         30739       485019.0     580372
# 2               217370.0         31202       488485.0     581604
# 3               210010.0         32175       492503.0     582410
# 4               207880.0         33263       495897.0     604087

# %%
scatter_matrix(Final_df, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a14b7c080>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a150ce3c8>]], dtype=object)

# %%
plt.show()

# %%
Final_df.corr()
# Out:
#                        Avg.Median Home price  AvgAnnualPay  EstHouseholds  \
# Avg.Median Home price               1.000000      0.848847       0.851533
# AvgAnnualPay                        0.848847      1.000000       0.991875
# EstHouseholds                       0.851533      0.991875       1.000000
# Employees                           0.824421      0.745824       0.803312
#
#                        Employees
# Avg.Median Home price   0.824421
# AvgAnnualPay            0.745824
# EstHouseholds           0.803312
# Employees               1.000000

# %% [markdown]
# ## Visualize each variable individually

# %%
Final_df.plot(kind="scatter", x="Avg.Median Home price", y="AvgAnnualPay", alpha=0.5)
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='AvgAnnualPay',data=Final_df,fit_reg=True) 
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='EstHouseholds',data=Final_df,fit_reg=True) 
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='Employees',data=Final_df,fit_reg=True) 
plt.show()
