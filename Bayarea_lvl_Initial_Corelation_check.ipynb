# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("resources/HistoricalData/BayAreaSummary.csv")

# %%
df.reset_index(inplace=True, drop=True)

# %%
df = df.drop(["Unnamed: 0", "Year"], axis=1)

# %%
df.head()
# Out:
#     TotalPop  HouseholdPop  EstHouseholds  Net_Migration  Immigration  \
# 0  6063929.0     5914746.0      2268498.0        26173.0      45028.0
# 1  6150405.0     5996580.0      2288446.0        32671.0      49980.0
# 2  6236622.0     6084002.0      2308925.0        30248.0      50644.0
# 3  6296661.0     6144064.0      2326344.0       -13351.0      41806.0
# 4  6330094.0     6180022.0      2344173.0       -18169.0      32940.0
#
#    Domestic_Migration  Population  Employers  Employees  AvgAnnualPay  \
# 0            -18855.0   6063929.0   184128.0  2942366.0  28240.444444
# 1            -17309.0   6150405.0   195298.0  2887645.0  30080.888889
# 2            -20396.0   6236622.0   202087.0  2879500.0  30708.555556
# 3            -55157.0   6296661.0   199363.0  2900397.0  31565.111111
# 4            -51109.0   6330094.0   214307.0  2964060.0  32787.777778
#
#    New Homes Constructed  HousingUnits  Avg.Median Home price  Interest_Rate  \
# 0                16396.0     2385091.0                 234197           9.34
# 1                16857.0     2401487.0                 233964           8.11
# 2                13781.0     2418344.0                 232320           7.13
# 3                14482.0     2432125.0                 238903           7.49
# 4                14371.0     2446607.0                 239315           7.85
#
#    HU_HH_Ratio  Pop_HU_Ratio
# 0     1.051397    269.285406
# 1     1.049396    270.309115
# 2     1.047390    269.799014
# 3     1.045471    268.907677
# 4     1.043697    267.561796

# %%
df_new = df[["Avg.Median Home price","TotalPop","HouseholdPop","EstHouseholds" ,"Net_Migration","Immigration","Interest_Rate"]]

# %%
df_new1 = df[["Avg.Median Home price","Domestic_Migration","Employers", "Employees","AvgAnnualPay","New Homes Constructed","Pop_HU_Ratio"]]

# %%
scatter_matrix(df_new, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E829DD9390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A083128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A066198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E829E308D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E829D87EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E829D878D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E829EACCC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E829EE0390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E829F05A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E829F380F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E829F61780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E829F89E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E829FBA4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E829FE3B70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A015240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A03C8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A2E5F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A316630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A33FCC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A372390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A398A20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A3CA0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A3F2780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A419E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A44B4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A475B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A4A7240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A4CF8D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A4F7F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A529630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A550CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A581390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A5ABA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A5DC0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A602780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A62CE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A65F4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A685B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A6B8240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A6E18D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A709F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A73A630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A764CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A796390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A7BCA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A7ED0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A815780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A83DE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82A86E4E0>]],
#       dtype=object)

# %%
plt.show()

# %%
scatter_matrix(df_new1, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BEAACC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BEA2E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C0FE898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C11DBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BB6B1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BB6B208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BBBAEF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BBEC5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BC15C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BC45320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BC6D9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BC9D080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BCC7710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BCF0DA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BD21470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BD47B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BD7B1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BDA2860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BDC9EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82BDFE5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C147C50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C178320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C19E9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C1D1080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C1F6710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C221DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C254470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C27AB00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C2AE1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C2D5860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C2FFEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C32F5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C359C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C389320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C3B09B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C3E2080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C40C710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C434DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C464470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C48DB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C4BF1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E829E3C828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E829E5D978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C4E0710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C509DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C53A470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C562B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C5951D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C5BC860>]],
#       dtype=object)

# %%
plt.show()

# %%
df.corr()
# Out:
#                        TotalPop  HouseholdPop  EstHouseholds  Net_Migration  \
# TotalPop               1.000000      0.999967       0.987640       0.176800
# HouseholdPop           0.999967      1.000000       0.987601       0.173730
# EstHouseholds          0.987640      0.987601       1.000000       0.123780
# Net_Migration          0.176800      0.173730       0.123780       1.000000
# Immigration           -0.041346     -0.041171      -0.043409      -0.155980
# Domestic_Migration     0.175526      0.172599       0.126114       0.975426
# Population             0.980072      0.980555       0.961840       0.110605
# Employers              0.938529      0.938395       0.923665       0.143713
# Employees              0.814899      0.816856       0.770957       0.294666
# AvgAnnualPay           0.970871      0.970787       0.967366       0.125181
# New Homes Constructed -0.075163     -0.069854      -0.057944      -0.305641
# HousingUnits           0.940152      0.940259       0.950957       0.045093
# Avg.Median Home price  0.799286      0.800972       0.814675      -0.180791
# Interest_Rate         -0.876945     -0.876772      -0.848218      -0.055196
# HU_HH_Ratio            0.152787      0.153174       0.153226      -0.215355
# Pop_HU_Ratio          -0.270808     -0.272385      -0.201112      -0.379374
#
#                        Immigration  Domestic_Migration  Population  Employers  \
# TotalPop                 -0.041346            0.175526    0.980072   0.938529
# HouseholdPop             -0.041171            0.172599    0.980555   0.938395
# EstHouseholds            -0.043409            0.126114    0.961840   0.923665
# Net_Migration            -0.155980            0.975426    0.110605   0.143713
# Immigration               1.000000           -0.369778   -0.073608  -0.171828
# Domestic_Migration       -0.369778            1.000000    0.120458   0.173508
# Population               -0.073608            0.120458    1.000000   0.973688
# Employers                -0.171828            0.173508    0.973688   1.000000
# Employees                 0.196253            0.233397    0.772258   0.694902
# AvgAnnualPay             -0.070669            0.133513    0.989333   0.972157
# New Homes Constructed     0.387770           -0.373992   -0.114884  -0.247501
# HousingUnits             -0.117368            0.068596    0.972967   0.969255
# Avg.Median Home price     0.177585           -0.209670    0.815038   0.738533
# Interest_Rate             0.208458           -0.098418   -0.932749  -0.933747
# HU_HH_Ratio              -0.246281           -0.147636    0.331107   0.429378
# Pop_HU_Ratio             -0.290989           -0.291945   -0.152323  -0.040030
#
#                        Employees  AvgAnnualPay  New Homes Constructed  \
# TotalPop                0.814899      0.970871              -0.075163
# HouseholdPop            0.816856      0.970787              -0.069854
# EstHouseholds           0.770957      0.967366              -0.057944
# Net_Migration           0.294666      0.125181              -0.305641
# Immigration             0.196253     -0.070669               0.387770
# Domestic_Migration      0.233397      0.133513              -0.373992
# Population              0.772258      0.989333              -0.114884
# Employers               0.694902      0.972157              -0.247501
# Employees               1.000000      0.735657               0.321188
# AvgAnnualPay            0.735657      1.000000              -0.154164
# New Homes Constructed   0.321188     -0.154164               1.000000
# HousingUnits            0.647884      0.988255              -0.192804
# Avg.Median Home price   0.725683      0.829636               0.291740
# Interest_Rate          -0.548573     -0.919119               0.307883
# HU_HH_Ratio            -0.160065      0.365919              -0.451536
# Pop_HU_Ratio           -0.698437     -0.079812              -0.515820
#
#                        HousingUnits  Avg.Median Home price  Interest_Rate  \
# TotalPop                   0.940152               0.799286      -0.876945
# HouseholdPop               0.940259               0.800972      -0.876772
# EstHouseholds              0.950957               0.814675      -0.848218
# Net_Migration              0.045093              -0.180791      -0.055196
# Immigration               -0.117368               0.177585       0.208458
# Domestic_Migration         0.068596              -0.209670      -0.098418
# Population                 0.972967               0.815038      -0.932749
# Employers                  0.969255               0.738533      -0.933747
# Employees                  0.647884               0.725683      -0.548573
# AvgAnnualPay               0.988255               0.829636      -0.919119
# New Homes Constructed     -0.192804               0.291740       0.307883
# HousingUnits               1.000000               0.807392      -0.925167
# Avg.Median Home price      0.807392               1.000000      -0.683790
# Interest_Rate             -0.925167              -0.683790       1.000000
# HU_HH_Ratio                0.451335               0.230073      -0.506030
# Pop_HU_Ratio               0.048504              -0.167926      -0.073316
#
#                        HU_HH_Ratio  Pop_HU_Ratio
# TotalPop                  0.152787     -0.270808
# HouseholdPop              0.153174     -0.272385
# EstHouseholds             0.153226     -0.201112
# Net_Migration            -0.215355     -0.379374
# Immigration              -0.246281     -0.290989
# Domestic_Migration       -0.147636     -0.291945
# Population                0.331107     -0.152323
# Employers                 0.429378     -0.040030
# Employees                -0.160065     -0.698437
# AvgAnnualPay              0.365919     -0.079812
# New Homes Constructed    -0.451536     -0.515820
# HousingUnits              0.451335      0.048504
# Avg.Median Home price     0.230073     -0.167926
# Interest_Rate            -0.506030     -0.073316
# HU_HH_Ratio               1.000000      0.742154
# Pop_HU_Ratio              0.742154      1.000000

# %%
Final_df = df[["Avg.Median Home price", "AvgAnnualPay","EstHouseholds", "Employees","Pop_HU_Ratio"]]

# %%
Final_df.head()
# Out:
#    Avg.Median Home price  AvgAnnualPay  EstHouseholds  Employees  Pop_HU_Ratio
# 0                 234197  28240.444444      2268498.0  2942366.0    269.285406
# 1                 233964  30080.888889      2288446.0  2887645.0    270.309115
# 2                 232320  30708.555556      2308925.0  2879500.0    269.799014
# 3                 238903  31565.111111      2326344.0  2900397.0    268.907677
# 4                 239315  32787.777778      2344173.0  2964060.0    267.561796

# %%
scatter_matrix(Final_df, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C863908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CB761D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CE09BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C873048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C8966D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C896710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C8F1438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C918AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C94A198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C973828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C999EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C9CB588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82C9F3C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CA242E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CA4B978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CA7F048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CAA86D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CAD0D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CB01438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CB28AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CE5B198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CE83828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CEACEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CEDF588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E82CF05C18>]],
#       dtype=object)

# %%
plt.show()

# %%
Final_df.corr()
# Out:
#                        Avg.Median Home price  AvgAnnualPay  EstHouseholds  \
# Avg.Median Home price               1.000000      0.829636       0.814675
# AvgAnnualPay                        0.829636      1.000000       0.967366
# EstHouseholds                       0.814675      0.967366       1.000000
# Employees                           0.725683      0.735657       0.770957
# Pop_HU_Ratio                       -0.167926     -0.079812      -0.201112
#
#                        Employees  Pop_HU_Ratio
# Avg.Median Home price   0.725683     -0.167926
# AvgAnnualPay            0.735657     -0.079812
# EstHouseholds           0.770957     -0.201112
# Employees               1.000000     -0.698437
# Pop_HU_Ratio           -0.698437      1.000000

# %% [markdown]
# ## Visualize each variable individually

# %%
Final_df.plot(kind="scatter", x="Avg.Median Home price", y="AvgAnnualPay", alpha=0.5)
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='AvgAnnualPay',data=Final_df,fit_reg=True) 
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='EstHouseholds',data=Final_df,fit_reg=True) 
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='Employees',data=Final_df,fit_reg=True) 
plt.show()
