# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("resources/HistoricalData/BayAreaGrowthSummary.csv")

# %%
df.reset_index(inplace=True, drop=True)

# %%
df = df.drop(["Unnamed: 0", "Year"], axis=1)

# %%
df.head()
# Out:
#    Population  Employers  Employees  AvgAnnualPay  New Homes Constructed  \
# 0     43782.0    23314.0   -86841.0   1413.333333                16396.0
# 1     86476.0    11170.0   -54721.0   1840.444444                16857.0
# 2     86217.0     6789.0    -8145.0    627.666667                13781.0
# 3     60039.0    -2724.0    20897.0    856.555556                14482.0
# 4     33433.0    14944.0    63663.0   1222.666667                14371.0
#
#    Avg.Median Home price  EstHouseholds  HHProdPerHouseholdGrowth
# 0                 234197      2268498.0                  7.227690
# 1                 233964      2288446.0                  7.366134
# 2                 232320      2308925.0                  5.968578
# 3                 238903      2326344.0                  6.225219
# 4                 239315      2344173.0                  6.130520

# %%
#df_new = df[["Avg.Median Home price","TotalPop","HouseholdPop","EstHouseholds" ,"Net_Migration","Immigration","Interest_Rate"]]

# %%
#df_new1 = df[["Avg.Median Home price","Domestic_Migration","Employers", "Employees","AvgAnnualPay","New Homes Constructed"]]

# %%
scatter_matrix(df, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028606D5B160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028606E305F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028606E57C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286070C9358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286070EE9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286070EEA20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000028607146748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002860716FDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286071A14A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286071CAB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286071FB208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028607221898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002860724BF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002860727A5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286072A1C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286072D2358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286072F99E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002860732C0B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000028607353748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002860737BDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286073AC4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286073D4B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028607404208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002860742C898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000028607455F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286074845F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002860847BC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286084AD358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286084D39E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286085050B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000028608530748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028608557DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286085874A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286085AFB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000286085E0208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028608607898>]],
#       dtype=object)

# %%
plt.show()

# %%
scatter_matrix(df_new1, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b55a908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b7bc9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b7df5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b815240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b84f240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b84f278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b8b0c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b8f3160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b92d6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b899208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b991c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b9c8cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ba04cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ba40cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ba75780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1baac7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bae97f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bb1f710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bb46e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bb83e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bbbbe80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bbf6e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bc31e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bc659b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bc9ca20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bcd8a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bd12a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bd47630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bd7f6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bdb86a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bdf35c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1be02b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1be600f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1be99400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bed2390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bf0e390>]], dtype=object)

# %%
plt.show()

# %%
df.corr()
# Out:
#                           Population  Employers  Employees  AvgAnnualPay  \
# Population                  1.000000  -0.000553   0.453263      0.218288
# Employers                  -0.000553   1.000000  -0.163540     -0.351757
# Employees                   0.453263  -0.163540   1.000000      0.641682
# AvgAnnualPay                0.218288  -0.351757   0.641682      1.000000
# New Homes Constructed      -0.263738  -0.064690  -0.093278      0.105926
# Avg.Median Home price      -0.222889  -0.097403   0.187985      0.240102
# EstHouseholds               0.090429  -0.242969   0.261689      0.336208
# HHProdPerHouseholdGrowth   -0.262287  -0.023491  -0.130583      0.053955
#
#                           New Homes Constructed  Avg.Median Home price  \
# Population                            -0.263738              -0.222889
# Employers                             -0.064690              -0.097403
# Employees                             -0.093278               0.187985
# AvgAnnualPay                           0.105926               0.240102
# New Homes Constructed                  1.000000               0.291740
# Avg.Median Home price                  0.291740               1.000000
# EstHouseholds                         -0.057944               0.814675
# HHProdPerHouseholdGrowth               0.988768               0.162320
#
#                           EstHouseholds  HHProdPerHouseholdGrowth
# Population                     0.090429                 -0.262287
# Employers                     -0.242969                 -0.023491
# Employees                      0.261689                 -0.130583
# AvgAnnualPay                   0.336208                  0.053955
# New Homes Constructed         -0.057944                  0.988768
# Avg.Median Home price          0.814675                  0.162320
# EstHouseholds                  1.000000                 -0.203461
# HHProdPerHouseholdGrowth      -0.203461                  1.000000

# %%
Final_df = df[["Avg.Median Home price", "AvgAnnualPay","Employees","Population"]]

# %%
Final_df.head()
# Out:
#    Avg.Median Home price  AvgAnnualPay  Employees  Population
# 0                 234197   1413.333333   -86841.0     43782.0
# 1                 233964   1840.444444   -54721.0     86476.0
# 2                 232320    627.666667    -8145.0     86217.0
# 3                 238903    856.555556    20897.0     60039.0
# 4                 239315   1222.666667    63663.0     33433.0

# %%
scatter_matrix(Final_df, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bf6cef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c3853c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c3aaf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c3e1f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c4264a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c4264e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c48bb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c4c3b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c5070b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c5344a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c56e4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c5a64a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c5dd9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c5e7b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c644f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c678f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c6c14a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c6f94a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c724978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c75f908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c79a908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c7d2908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c76a5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c83d438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c876908>]], dtype=object)

# %%
plt.show()

# %%
Final_df.corr()
# Out:
#                        Avg.Median Home price  AvgAnnualPay  Employees  \
# Avg.Median Home price               1.000000      0.240102   0.187985
# AvgAnnualPay                        0.240102      1.000000   0.641682
# Employees                           0.187985      0.641682   1.000000
# Population                         -0.222889      0.218288   0.453263
#
#                        Population
# Avg.Median Home price   -0.222889
# AvgAnnualPay             0.218288
# Employees                0.453263
# Population               1.000000

# %% [markdown]
# ## Visualize each variable individually

# %%
Final_df.plot(kind="scatter", x="Avg.Median Home price", y="AvgAnnualPay", alpha=0.5)
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='AvgAnnualPay',data=Final_df,fit_reg=True) 
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='Population',data=Final_df,fit_reg=True) 
plt.show()

# %%
sns.lmplot(x='Avg.Median Home price',y='Employees',data=Final_df,fit_reg=True) 
plt.show()
